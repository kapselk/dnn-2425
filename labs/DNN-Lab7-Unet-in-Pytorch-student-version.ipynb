# %% [markdown]
# Code based on https://github.com/pytorch/examples/blob/master/mnist/main.py
#
# In this exercise, we are going to implement a [UNet-like](https://arxiv.org/pdf/1505.04597.pdf) architecture for the semantic segmentation task.
# The model is trained on the [CamVid](https://mi.eng.cam.ac.uk/research/projects/VideoRec/CamVid/) dataset.
#
# Tasks:
#
#     1. Implement the missing pieces in the code.
#     2. Check that the given implementation reaches over 70% test accuracy after 10-15 epochs.
#     3. Check how segmentations produced by the model compare to ground truth segementations.

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torchvision import transforms
from torchvision.transforms.functional import InterpolationMode
from PIL import Image
from typing import List, Tuple

# %%
class UNetConvolutionStack(nn.Module):
    def __init__(self, in_channel: int, out_channel: int):
        super(UNetConvolutionStack, self).__init__()
        self.conv = nn.Sequential(
            nn.Conv2d(in_channel, out_channel, kernel_size=3, padding=1),
            nn.BatchNorm2d(out_channel),
            nn.LeakyReLU(),
        )

    def forward(self, x):
        x = self.conv(x)
        return x

# %%
class EncoderStack(nn.Module):
    def __init__(self, in_channel: int, out_channel: int, first_layer: bool = False):
        super(EncoderStack, self).__init__()
        if first_layer:
            self.down = nn.Sequential(
                UNetConvolutionStack(in_channel, out_channel),
                UNetConvolutionStack(out_channel, out_channel),
            )
        else:
            self.down = nn.Sequential(
                nn.MaxPool2d((2, 2)),
                UNetConvolutionStack(in_channel, out_channel),
                UNetConvolutionStack(out_channel, out_channel),
            )

    def forward(self, x: torch.Tensor) -> torch.Tensor:
        x = self.down(x)
        return x

# %%
class DecoderStack(nn.Module):
    def __init__(self, in_channel, out_channel):
        super(DecoderStack, self).__init__()
        self.upsample = nn.ConvTranspose2d(
            in_channel, in_channel, 3, stride=2, padding=1
        )
        self.up = nn.Sequential(
            UNetConvolutionStack(in_channel + out_channel, out_channel),
            UNetConvolutionStack(out_channel, out_channel),
        )

    def forward(self, x: torch.Tensor, y: torch.Tensor) -> torch.Tensor:
        # TODO: implement skip connections.
        # hint: x is the output of previous decoder layer,
        # y is the output of corresponding encoder layer.
        # Based on the arguments of the constructor,
        # how should x and y be combined?
        # print(f"x.shape = {x.shape} ; y.shape = {y.shape}")
        x = self.upsample(x, output_size=y.shape)
        x = torch.cat([x, y], dim=1)
        x = self.up(x)
        return x

# %%
class UNet(nn.Module):
    def __init__(self, encoder_channels: int, decoder_channels: int, num_classes: int):
        super(UNet, self).__init__()
        self.encoder = nn.ModuleList()
        self.decoder = nn.ModuleList()
        self.conv = nn.Conv2d(
            decoder_channels[-1], num_classes, kernel_size=3, padding=1
        )

        encoder_sizes = zip(
            range(len(encoder_channels)), encoder_channels, encoder_channels[1:]
        )
        for idx, in_size, out_size in encoder_sizes:
            if idx > 0:
                self.encoder.append(EncoderStack(in_size, out_size))
            else:
                self.encoder.append(EncoderStack(in_size, out_size, first_layer=True))

        decoder_sizes = zip(decoder_channels, decoder_channels[1:])
        for in_size, out_size in decoder_sizes:
            self.decoder.append(DecoderStack(in_size, out_size))

    def forward(self, x: torch.Tensor) -> torch.Tensor:
        # TODO: implement UNet's forward pass.
        # hint: Remember to store outputs of subsequent
        # encoder layers to use as input to decoder layers!
        # Do not forget about the final convolution.
        encoder_outputs = []
        for layer in self.encoder:
            x = layer(x)
            encoder_outputs.append(x)
        x = encoder_outputs.pop()
        for layer, encoder_output in zip(self.decoder, encoder_outputs[::-1]):
            x = layer(x, encoder_output)
        x = self.conv(x)
        return x

# %%
def train(
    model: torch.nn.Module,
    device: torch.device,
    train_loader: torch.utils.data.DataLoader,
    optimizer: torch.optim.Optimizer,
    epoch: int,
    log_interval: int,
):
    model.train()
    correct = 0
    for batch_idx, (data, target) in enumerate(train_loader):
        data, target = data.to(device), target.to(device)
        optimizer.zero_grad()
        output = model(data)
        log_probs = F.log_softmax(output, dim=1)
        loss = F.nll_loss(log_probs, target)
        pred = log_probs.argmax(
            dim=1, keepdim=True
        )  # get the index of the max log-probability
        correct += pred.eq(target.view_as(pred)).sum().item()
        loss.backward()
        optimizer.step()
        if batch_idx % log_interval == 0:
            _, _, image_width, image_height = data.size()
            print(
                "Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f}".format(
                    epoch,
                    batch_idx * len(data),
                    len(train_loader.dataset),
                    100.0 * batch_idx / len(train_loader),
                    loss.item(),
                )
            )
    print(
        "Train accuracy: {}/{} ({:.0f}%)".format(
            correct,
            (len(train_loader.dataset) * image_width * image_height),
            100.0 * correct / (len(train_loader.dataset) * image_width * image_height),
        )
    )


def test(
    model: torch.nn.Module,
    device: torch.device,
    test_loader: torch.utils.data.DataLoader,
):
    model.eval()
    test_loss = 0
    correct = 0
    with torch.no_grad():
        for data, target in test_loader:
            data, target = data.to(device), target.to(device)
            output = model(data)
            log_probs = F.log_softmax(output, dim=1)
            test_loss += F.nll_loss(
                log_probs,
                target,
                reduction="sum",
            ).item()  # sum up batch loss
            pred = log_probs.argmax(
                dim=1, keepdim=True
            )  # get the index of the max log-probability
            correct += pred.eq(target.view_as(pred)).sum().item()
    _, _, image_width, image_height = data.size()
    test_loss /= len(test_loader.dataset) * image_width * image_height

    print(
        "Test set: Average loss: {:.4f}, Accuracy: {}/{} ({:.0f}%)\n".format(
            test_loss,
            correct,
            (len(test_loader.dataset) * image_width * image_height),
            100.0 * correct / (len(test_loader.dataset) * image_width * image_height),
        )
    )

# %%
batch_size = 50
test_batch_size = 1000
epochs = 15
lr = 2e-3
use_cuda = True
seed = 1
log_interval = 10
test_size = 80
data_root = "../data"

imagenet_mean = [0.485, 0.456, 0.406]
imagenet_std = [0.229, 0.224, 0.225]
num_classes = 32

# %%
use_cuda = use_cuda and torch.cuda.is_available()

torch.manual_seed(seed)
device = torch.device("cuda" if use_cuda else "cpu")

train_kwargs = {"batch_size": batch_size}
test_kwargs = {"batch_size": test_batch_size}
if use_cuda:
    cuda_kwargs = {"num_workers": 1, "pin_memory": True, "shuffle": True}
    train_kwargs.update(cuda_kwargs)
    test_kwargs.update(cuda_kwargs)

# %%
class SegmentationDataset(torch.utils.data.Dataset):
    def __init__(
        self,
        root_dir: str,
        filenames: List[str],
        transform: torch.nn.Module = None,
        target_transform: torch.nn.Module = None,
    ):
        self.root_dir = root_dir
        self.filenames = filenames
        self.transform = transform
        self.target_transform = target_transform
        self.transformed_data_dir = os.path.join(root_dir, "transformed")
        if not os.path.exists(self.transformed_data_dir):
            os.mkdir(self.transformed_data_dir)
            os.mkdir(os.path.join(self.transformed_data_dir, "images"))
            os.mkdir(os.path.join(self.transformed_data_dir, "labels"))

    def __len__(self) -> int:
        return len(self.filenames)

    def __getitem__(self, idx: int) -> Tuple[torch.Tensor, torch.Tensor]:
        filename = self.filenames[idx]

        transformed_image_path = os.path.join(
            self.transformed_data_dir, "images", filename
        )
        transformed_target_path = os.path.join(
            self.transformed_data_dir, "labels", filename
        )
        if os.path.exists(transformed_image_path) and os.path.exists(
            transformed_target_path
        ):
            img = torch.load(transformed_image_path, weights_only=False)
            target = torch.load(transformed_target_path, weights_only=False)
        else:
            image_path = os.path.join(
                self.root_dir, "701_StillsRaw_full", f"{filename}.png"
            )
            target_path = os.path.join(self.root_dir, "labels", f"{filename}_L.png")

            img = Image.open(image_path).convert("RGB")
            target = Image.open(target_path)

            if self.transform is not None:
                img = self.transform(img)
            if self.target_transform is not None:
                target = self.target_transform(target)
            # Applying transformations takes a long. So we do this only once,
            # then save transformed tensors to files and read them when they are needed again.
            # This significantly speeds up next iterations over dataset.
            torch.save(img, transformed_image_path)
            torch.save(target, transformed_target_path)

        return img, target

# %%
# Download dataset
# !mkdir -p {data_root}
# !wget -c -P {data_root} https://datasets.cms.waikato.ac.nz/ufdl/data/camvid/701_StillsRaw_full.zip
# !wget -c -P {data_root} https://datasets.cms.waikato.ac.nz/ufdl/data/camvid/LabeledApproved_full.zip
# !wget -c -P {data_root} https://datasets.cms.waikato.ac.nz/ufdl/data/camvid/label_colors.txt
# !if [[ ! -d {data_root}/701_StillsRaw_full ]]; then unzip {data_root}/701_StillsRaw_full.zip -d {data_root}; fi
# !if [[ ! -d {data_root}/labels ]]; then unzip {data_root}/LabeledApproved_full.zip -d {data_root}/labels; fi
# !rm {data_root}/701_StillsRaw_full/Seq05VD_f02610.png 2>/dev/null
# !rm {data_root}/labels/Seq05VD_f02610_L.png 2>/dev/null
# Out:
# --2024-11-28 14:20:07--  https://datasets.cms.waikato.ac.nz/ufdl/data/camvid/701_StillsRaw_full.zip
# Resolving datasets.cms.waikato.ac.nz (datasets.cms.waikato.ac.nz)... 172.67.20.185, 104.22.23.233, 104.22.22.233, ...
# Connecting to datasets.cms.waikato.ac.nz (datasets.cms.waikato.ac.nz)|172.67.20.185|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 584553911 (557M) [application/zip]
# Saving to: ‘../data/701_StillsRaw_full.zip’
#
# 701_StillsRaw_full. 100%[===================>] 557.47M  39.7MB/s    in 15s
#
# 2024-11-28 14:20:22 (38.2 MB/s) - ‘../data/701_StillsRaw_full.zip’ saved [584553911/584553911]
#
# --2024-11-28 14:20:22--  https://datasets.cms.waikato.ac.nz/ufdl/data/camvid/LabeledApproved_full.zip
# Resolving datasets.cms.waikato.ac.nz (datasets.cms.waikato.ac.nz)... 172.67.20.185, 104.22.23.233, 104.22.22.233, ...
# Connecting to datasets.cms.waikato.ac.nz (datasets.cms.waikato.ac.nz)|172.67.20.185|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 16567585 (16M) [application/zip]
# Saving to: ‘../data/LabeledApproved_full.zip’
#
# LabeledApproved_ful 100%[===================>]  15.80M  76.9MB/s    in 0.2s
#
# 2024-11-28 14:20:22 (76.9 MB/s) - ‘../data/LabeledApproved_full.zip’ saved [16567585/16567585]
#
# --2024-11-28 14:20:22--  https://datasets.cms.waikato.ac.nz/ufdl/data/camvid/label_colors.txt
# Resolving datasets.cms.waikato.ac.nz (datasets.cms.waikato.ac.nz)... 172.67.20.185, 104.22.23.233, 104.22.22.233, ...
# Connecting to datasets.cms.waikato.ac.nz (datasets.cms.waikato.ac.nz)|172.67.20.185|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length:
#   inflating: ../data/labels/Seq05VD_f00180_L.png
#   inflating: ../data/labels/Seq05VD_f00210_L.png
#   inflating: ../data/labels/Seq05VD_f00240_L.png
#   inflating: ../data/labels/Seq05VD_f00270_L.png
#   inflating: ../data/labels/Seq05VD_f00300_L.png
#   inflating: ../data/labels/Seq05VD_f00330_L.png
#   inflating: ../data/labels/Seq05VD_f00360_L.png
#   inflating: ../data/labels/Seq05VD_f00390_L.png
#   inflating: ../data/labels/Seq05VD_f00420_L.png
#   inflating: ../data/labels/Seq05VD_f00450_L.png
#   inflating: ../data/labels/Seq05VD_f00480_L.png
#   inflating: ../data/labels/Seq05VD_f00510_L.png
#   inflating: ../data/labels/Seq05VD_f00540_L.png
#   inflating: ../data/labels/Seq05VD_f00570_L.png
#   inflating: ../data/labels/Seq05VD_f00600_L.png
#   inflating: ../data/labels/Seq05VD_f00630_L.png
#   inflating: ../data/labels/Seq05VD_f00660_L.png
#   inflating: ../data/labels/Seq05VD_f00690_L.png
#   inflating: ../data/labels/Seq05VD_f00720_L.png
#   inflating: ../data/labels/Seq05VD_f00750_L.png
#   inflating: ../data/labels/Seq05VD_f00780_L.png
#   inflating: ../data/labels/Seq05VD_f00810_L.png
#   inflating: ../data/labels/Seq05VD_f00840_L.png
#   inflating: ../data/labels/Seq05VD_f00870_L.png
#   inflating: ../data/labels/Seq05VD_f00900_L.png
#   inflating: ../data/labels/Seq05VD_f00930_L.png
#   inflating: ../data/labels/Seq05VD_f00960_L.png
#   inflating: ../data/labels/Seq05VD_f00990_L.png
#   inflating: ../data/labels/Seq05VD_f01020_L.png
#   inflating: ../data/labels/Seq05VD_f01050_L.png
#   inflating: ../data/labels/Seq05VD_f01080_L.png
#   inflating: ../data/labels/Seq05VD_f01110_L.png
#   inflating: ../data/labels/Seq05VD_f01140_L.png
#   inflating: ../data/labels/Seq05VD_f01170_L.png
#   inflating: ../data/labels/Seq05VD_f01200_L.png
#   inflating: ../data/labels/Seq05VD_f01230_L.png
#   inflating: ../data/labels/Seq05VD_f01260_L.png
#   inflating: ../data/labels/Seq05VD_f01290_L.png
#   inflating: ../data/labels/Seq05VD_f01320_L.png
#   inflating: ../data/labels/Seq05VD_f01350_L.png
#   inflating: ../data/labels/Seq05VD_f01380_L.png
#   inflating: ../data/labels/Seq05VD_f01410_L.png
#   inflating: ../data/labels/Seq05VD_f01440_L.png
#   inflating: ../data/labels/Seq05VD_f01470_L.png
#   inflating: ../data/labels/Seq05VD_f01500_L.png
#   inflating: ../data/labels/Seq05VD_f01530_L.png
#   inflating: ../data/labels/Seq05VD_f01560_L.png
#   inflating: ../data/labels/Seq05VD_f01590_L.png
#   inflating: ../data/labels/Seq05VD_f01620_L.png
#   inflating: ../data/labels/Seq05VD_f01650_L.png
#   inflating: ../data/labels/Seq05VD_f01680_L.png
#   inflating: ../data/labels/Seq05VD_f01710_L.png
#   inflating: ../data/labels/Seq05VD_f01740_L.png
#   inflating: ../data/labels/Seq05VD_f01770_L.png
#   inflating: ../data/labels/Seq05VD_f01800_L.png
#   inflating: ../data/labels/Seq05VD_f01830_L.png
#   inflating: ../data/labels/Seq05VD_f01860_L.png
#   inflating: ../data/labels/Seq05VD_f01890_L.png
#   inflating: ../data/labels/Seq05VD_f01920_L.png
#   inflating: ../data/labels/Seq05VD_f01950_L.png
#   inflating: ../data/labels/Seq05VD_f01980_L.png
#   inflating: ../data/labels/Seq05VD_f02010_L.png
#   inflating: ../data/labels/Seq05VD_f02040_L.png
#   inflating: ../data/labels/Seq05VD_f02070_L.png
#   inflating: ../data/labels/Seq05VD_f02100_L.png
#   inflating: ../data/labels/Seq05VD_f02130_L.png
#   inflating: ../data/labels/Seq05VD_f02160_L.png
#   inflating: ../data/labels/Seq05VD_f02190_L.png
#   inflating: ../data/labels/Seq05VD_f02220_L.png
#   inflating: ../data/labels/Seq05VD_f02250_L.png
#   inflating: ../data/labels/Seq05VD_f02280_L.png
#   inflating: ../data/labels/Seq05VD_f02310_L.png
#   inflating: ../data/labels/Seq05VD_f02340_L.png
#   inflating: ../data/labels/Seq05VD_f02370_L.png
#   inflating: ../data/labels/Seq05VD_f02400_L.png
#   inflating: ../data/labels/Seq05VD_f02430_L.png
#   inflating: ../data/labels/Seq05VD_f02460_L.png
#   inflating: ../data/labels/Seq05VD_f02490_L.png
#   inflating: ../data/labels/Seq05VD_f02520_L.png
#   inflating: ../data/labels/Seq05VD_f02550_L.png
#   inflating: ../data/labels/Seq05VD_f02580_L.png
#   inflating: ../data/labels/Seq05VD_f02610_L.png
#   inflating: ../data/labels/Seq05VD_f02640_L.png
#   inflating: ../data/labels/Seq05VD_f02670_L.png
#   inflating: ../data/labels/Seq05VD_f02700_L.png
#   inflating: ../data/labels/Seq05VD_f02730_L.png
#   inflating: ../data/labels/Seq05VD_f02760_L.png
#   inflating: ../data/labels/Seq05VD_f02790_L.png
#   inflating: ../data/labels/Seq05VD_f02820_L.png
#   inflating: ../data/labels/Seq05VD_f02850_L.png
#   inflating: ../data/labels/Seq05VD_f02880_L.png
#   inflating: ../data/labels/Seq05VD_f02910_L.png
#   inflating: ../data/labels/Seq05VD_f02940_L.png
#   inflating: ../data/labels/Seq05VD_f02970_L.png
#   inflating: ../data/labels/Seq05VD_f03000_L.png
#   inflating: ../data/labels/Seq05VD_f03030_L.png
#   inflating: ../data/labels/Seq05VD_f03060_L.png
#   inflating: ../data/labels/Seq05VD_f03090_L.png
#   inflating: ../data/labels/Seq05VD_f03120_L.png
#   inflating: ../data/labels/Seq05VD_f03150_L.png
#   inflating: ../data/labels/Seq05VD_f03180_L.png
#   inflating: ../data/labels/Seq05VD_f03210_L.png
#   inflating: ../data/labels/Seq05VD_f03240_L.png
#   inflating: ../data/labels/Seq05VD_f03270_L.png
#   inflating: ../data/labels/Seq05VD_f03300_L.png
#   inflating: ../data/labels/Seq05VD_f03330_L.png
#   inflating: ../data/labels/Seq05VD_f03360_L.png
#   inflating: ../data/labels/Seq05VD_f03390_L.png
#   inflating: ../data/labels/Seq05VD_f03420_L.png
#   inflating: ../data/labels/Seq05VD_f03450_L.png
#   inflating: ../data/labels/Seq05VD_f03480_L.png
#   inflating: ../data/labels/Seq05VD_f03510_L.png
#   inflating: ../data/labels/Seq05VD_f03540_L.png
#   inflating: ../data/labels/Seq05VD_f03570_L.png
#   inflating: ../data/labels/Seq05VD_f03600_L.png
#   inflating: ../data/labels/Seq05VD_f03630_L.png
#   inflating: ../data/labels/Seq05VD_f03660_L.png
#   inflating: ../data/labels/Seq05VD_f03690_L.png
#   inflating: ../data/labels/Seq05VD_f03720_L.png
#   inflating: ../data/labels/Seq05VD_f03750_L.png
#   inflating: ../data/labels/Seq05VD_f03780_L.png
#   inflating: ../data/labels/Seq05VD_f03810_L.png
#   inflating: ../data/labels/Seq05VD_f03840_L.png
#   inflating: ../data/labels/Seq05VD_f03870_L.png
#   inflating: ../data/labels/Seq05VD_f03900_L.png
#   inflating: ../data/labels/Seq05VD_f03930_L.png
#   inflating: ../data/labels/Seq05VD_f03960_L.png
#   inflating: ../data/labels/Seq05VD_f03990_L.png
#   inflating: ../data/labels/Seq05VD_f04020_L.png
#   inflating: ../data/labels/Seq05VD_f04050_L.png
#   inflating: ../data/labels/Seq05VD_f04080_L.png
#   inflating: ../data/labels/Seq05VD_f04110_L.png
#   inflating: ../data/labels/Seq05VD_f04140_L.png
#   inflating: ../data/labels/Seq05VD_f04170_L.png
#   inflating: ../data/labels/Seq05VD_f04200_L.png
#   inflating: ../data/labels/Seq05VD_f04230_L.png
#   inflating: ../data/labels/Seq05VD_f04260_L.png
#   inflating: ../data/labels/Seq05VD_f04290_L.png
#   inflating: ../data/labels/Seq05VD_f04320_L.png
#   inflating: ../data/labels/Seq05VD_f04350_L.png
#   inflating: ../data/labels/Seq05VD_f04380_L.png
#   inflating: ../data/labels/Seq05VD_f04410_L.png
#   inflating: ../data/labels/Seq05VD_f04440_L.png
#   inflating: ../data/labels/Seq05VD_f04470_L.png
#   inflating: ../data/labels/Seq05VD_f04500_L.png
#   inflating: ../data/labels/Seq05VD_f04530_L.png
#   inflating: ../data/labels/Seq05VD_f04560_L.png
#   inflating: ../data/labels/Seq05VD_f04590_L.png
#   inflating: ../data/labels/Seq05VD_f04620_L.png
#   inflating: ../data/labels/Seq05VD_f04650_L.png
#   inflating: ../data/labels/Seq05VD_f04680_L.png
#   inflating: ../data/labels/Seq05VD_f04710_L.png
#   inflating: ../data/labels/Seq05VD_f04740_L.png
#   inflating: ../data/labels/Seq05VD_f04770_L.png
#   inflating: ../data/labels/Seq05VD_f04800_L.png
#   inflating: ../data/labels/Seq05VD_f04830_L.png
#   inflating: ../data/labels/Seq05VD_f04860_L.png
#   inflating: ../data/labels/Seq05VD_f04890_L.png
#   inflating: ../data/labels/Seq05VD_f04920_L.png
#   inflating: ../data/labels/Seq05VD_f04950_L.png
#   inflating: ../data/labels/Seq05VD_f04980_L.png
#   inflating: ../data/labels/Seq05VD_f05010_L.png
#   inflating: ../data/labels/Seq05VD_f05040_L.png
#   inflating: ../data/labels/Seq05VD_f05070_L.png
#   inflating: ../data/labels/Seq05VD_f05100_L.png

# %%
labels_colors = open(os.path.join(data_root, "label_colors.txt"), "r").readlines()
labels_colors = [
    torch.tensor(list(map(int, line.split()[:3]))) for line in labels_colors
]
filenames = [
    fname[:-4] for fname in os.listdir(os.path.join(data_root, "701_StillsRaw_full"))
]
filenames_train = filenames[:-test_size]
filenames_test = filenames[-test_size:]


def rgb_to_single_color(x: torch.Tensor) -> torch.Tensor:
    ret = torch.zeros(x.shape[1], x.shape[2], dtype=torch.long)
    for single_color, rgb_colors in enumerate(labels_colors):
        rgb_colors = rgb_colors.unsqueeze(1).unsqueeze(2)
        indices = torch.all(torch.eq(x, rgb_colors), dim=0)
        ret[indices] = single_color
    return ret


input_resize = transforms.Resize((240, 320))
input_transform = transforms.Compose(
    [
        input_resize,
        transforms.ToTensor(),
        transforms.Normalize(imagenet_mean, imagenet_std),
    ]
)

target_resize = transforms.Resize((240, 320), interpolation=InterpolationMode.NEAREST)
target_transform = transforms.Compose(
    [
        target_resize,
        transforms.PILToTensor(),
        transforms.Lambda(rgb_to_single_color),
    ]
)

train_dataset = SegmentationDataset(
    data_root,
    filenames_train,
    transform=input_transform,
    target_transform=target_transform,
)
test_dataset = SegmentationDataset(
    data_root,
    filenames_test,
    transform=input_transform,
    target_transform=target_transform,
)

train_loader = torch.utils.data.DataLoader(train_dataset, **train_kwargs)
test_loader = torch.utils.data.DataLoader(test_dataset, **train_kwargs)

# %%
model = UNet(
    encoder_channels=[3, 8, 16, 32],
    decoder_channels=[32, 16, 8],
    num_classes=num_classes,
).to(device)
optimizer = optim.Adam(model.parameters(), lr=lr)

for epoch in range(1, epochs + 1):
    train(model, device, train_loader, optimizer, epoch, log_interval)
    test(model, device, test_loader)
# Out:
# Train Epoch: 1 [0/620 (0%)]	Loss: 3.571073
# Train Epoch: 1 [500/620 (77%)]	Loss: 2.501887
# Train accuracy: 14261630/47616000 (30%)
# Test set: Average loss: 2.5128, Accuracy: 2476974/6144000 (40%)
#
# Train Epoch: 2 [0/620 (0%)]	Loss: 2.266596
# Train Epoch: 2 [500/620 (77%)]	Loss: 1.703768
# Train accuracy: 27290981/47616000 (57%)
# Test set: Average loss: 1.9308, Accuracy: 2902268/6144000 (47%)
#
# Train Epoch: 3 [0/620 (0%)]	Loss: 1.595591
# Train Epoch: 3 [500/620 (77%)]	Loss: 1.412587
# Train accuracy: 28951491/47616000 (61%)
# Test set: Average loss: 1.4932, Accuracy: 3704174/6144000 (60%)
#
# Train Epoch: 4 [0/620 (0%)]	Loss: 1.351009
# Train Epoch: 4 [500/620 (77%)]	Loss: 1.273312
# Train accuracy: 29696807/47616000 (62%)
# Test set: Average loss: 1.3392, Accuracy: 3896660/6144000 (63%)
#
# Train Epoch: 5 [0/620 (0%)]	Loss: 1.267855
# Train Epoch: 5 [500/620 (77%)]	Loss: 1.130340
# Train accuracy: 31532182/47616000 (66%)
# Test set: Average loss: 1.2688, Accuracy: 3990652/6144000 (65%)
#
# Train Epoch: 6 [0/620 (0%)]	Loss: 1.135656
# Train Epoch: 6 [500/620 (77%)]	Loss: 1.125355
# Train accuracy: 32661659/47616000 (69%)
# Test set: Average loss: 1.1578, Accuracy: 4247992/6144000 (69%)
#
# Train Epoch: 7 [0/620 (0%)]	Loss: 1.102896
# Train Epoch: 7 [500/620 (77%)]	Loss: 1.101001
# Train accuracy: 32969148/47616000 (69%)
# Test set: Average loss: 1.2147, Accuracy: 4060247/6144000 (66%)
#
# Train Epoch: 8 [0/620 (0%)]	Loss: 1.011142
# Train Epoch: 8 [500/620 (77%)]	Loss: 1.015526
# Train accuracy: 33928534/47616000 (71%)
# Test set: Average loss: 1.2282, Accuracy: 4085313/6144000 (66%)
#
# Train Epoch: 9 [0/620 (0%)]	Loss: 1.001041
# Train Epoch: 9 [500/620 (77%)]	Loss: 0.964267
# Train accuracy: 34279034/47616000 (72%)
# Test set: Average loss: 1.0154, Accuracy: 4394341/6144000 (72%)
#
# Train Epoch: 10 [0/620 (0%)]	Loss: 0.985721
# Train Epoch: 10 [500/620 (77%)]	Loss: 1.025684
# Train accuracy: 34708236/47616000 (73%)
# Test set: Average loss: 0.9865, Accuracy: 4474619/6144000 (73%)
#
# Train Epoch: 11 [0/620 (0%)]	Loss: 0.967652
# Train Epoch: 11 [500/620 (77%)]	Loss: 0.952613
# Train accuracy: 34872988/47616000 (73%)
# Test set: Average loss: 1.0111, Accuracy: 4354393/6144000 (71%)
#
# Train Epoch: 12 [0/620 (0%)]	Loss: 0.946437
# Train Epoch: 12 [500/620 (77%)]	Loss: 0.865651
# Train accuracy: 35180706/47616000 (74%)
# Test set: Average loss: 0.9188, Accuracy: 4579854/6144000 (75%)
#
# Train Epoch: 13 [0/620 (0%)]	Loss: 0.879324
# Train Epoch: 13 [500/620 (77%)]	Loss: 0.917713
# Train accuracy: 35750816/47616000 (75%)
# Test set: Average loss: 0.9117, Accuracy: 4585545/6144000 (75%)
#
# Train Epoch: 14 [0/620 (0%)]	Loss: 0.931416
# Train Epoch: 14 [500/620 (77%)]	Loss: 0.882502
# Train accuracy: 35641048/47616000 (75%)
# Test set: Average loss: 0.9516, Accuracy: 4502773/6144000 (73%)
#
# Train Epoch: 15 [0/620 (0%)]	Loss: 0.922011
# Train Epoch: 15 [500/620 (77%)]	Loss: 0.839374
# Train accuracy: 35715271/47616000 (75%)
# Test set: Average loss: 0.8950, Accuracy: 4603652/6144000 (75%)

# %%
data, target = next(iter(test_loader))
output = model(data.to(device))
pred = output.argmax(dim=1, keepdim=True).to("cpu")

for i in range(5):
    image = data[i].permute(1, 2, 0).numpy()
    target_segmentation = target[i]
    pred_segmentation = pred[i].squeeze()

    fig, axes = plt.subplots(
        1, 2, figsize=(10, 20), gridspec_kw={"width_ratios": [1, 2]}
    )
    segmentations = torch.hstack([target_segmentation, pred_segmentation])
    segmentations = segmentations.unsqueeze(2).numpy()
    axes[0].imshow(np.clip(image, 0, 1))
    axes[0].axis("off")
    axes[1].imshow(segmentations)
    axes[1].axis("off")

    plt.tight_layout()
    plt.show()
